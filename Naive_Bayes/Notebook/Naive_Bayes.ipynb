# %% [markdown]
# <a href="https://colab.research.google.com/github/JefteLG/Estudos/blob/main/Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1>Naive Bayes</h1><center>

# %% [markdown]
# # Conteudo para estudos:

# %% [markdown]
# DOCUMENTOS {
#
# [CLASSIFICADORES BAEYSIANOS](http://www.facom.ufu.br/~backes/pgc204/Aula05-ClassificadoresBaeysianos.pdf)
#
# [Aprendizagem Bayesiana](http://www.eletrica.ufpr.br/ufpr2/professor/36/TE808/5-NaiveBayes-AM.pdf)
#
# [Aprendizado Bayesiano Aplicado ao Processamento de Línguas Naturais](https://sites.icmc.usp.br/taspardo/NILCTR0225-PardoNunes.pdf)
#
# [Naïve Bayes Classifier](http://ww2.inf.ufg.br/~gustavo/courses/grad/pra/lectures/bayes.pdf)
#
# [Classificação: Naive Bayes](https://folivetti.github.io/courses/AprendizadoMaquina/PDF/Aula08.pdf)
#
# [Um assistente de feedback para o serviço de filtragem do software direto](https://www.lume.ufrgs.br/bitstream/handle/10183/2596/000373347.pdf?sequence=1)
#
# [Classificador Naive Bayes](http://www2.dbd.puc-rio.br/pergamum/tesesabertas/0420991_06_cap_04.pdf)
#
# }

# %% [markdown]
# VIDEOS {
#
# [Ciência de Dados: Teoria da Decisão Bayesiana na classificação de dados](https://www.youtube.com/watch?v=8zAKWEOdGsg&ab_channel=FranciscoRodrigues)
#
# [Ciência de Dados: Classificador Naive Bayes](https://www.youtube.com/watch?v=Bk2mSIMw_XE&ab_channel=FranciscoRodrigues)
#
# [Entenda o Teorema de Bayes (ótima explicação!)](https://www.youtube.com/watch?v=I643PqSrETM&ab_channel=Did%C3%A1ticaTech)
#
# }

# %% [markdown]
# Reforçar {
#
# [Ciência de Dados: Tipos de aprendizado](https://www.youtube.com/watch?v=PMNl9qaxhZA&ab_channel=FranciscoRodrigues)
#
# }

# %% [markdown]
# # Teorema de Bayes (conceito teórico)

# %% [markdown]
# - Frequentemente, uma informação é apresentada na forma de probabilidade condicional.
#
#  - Probabilidade de um evento ocorrer dada uma condição.
#
#    - A probabilidade de ocorrer um evento B, na condição de que outro evento A já tenha ocorrido.
#
# - Esse tipo de problema é tratado usando o Teorema de Bayes.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# - O Teorema de Bayes relaciona as probabilidades de A e B com suas respectivas probabilidades condicionadas.

# %% [markdown]
# ![bayes.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - P(A) e P(B): Probabilidade a priori de A e B.
# - P(B|A) e P(A|B): Probabilidade a posteriori de B condicional a A e de A condicional a B respectivamente.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# Probabilidade a priori:
#  - Probabilidade dada sem conhecimento de qualquer outro evento.
#    - Probabilidade de tirar um número par num dado 1/2.
#
# Probabilidade a posteriori:
# - É a probabilidade condicional que é atribuída quando um evento relevante é considerado.
#   - Ao lançarmos um dado N vezes, teremos a posteriori que a distribuição dos valores tedem ao previsto a priori.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# **Exemplo**
# - Um médico sabe que a meningite causa torcicolo 50% das vezes.
#   - Probabilidade a priori de qualquer paciente ter meningite: **1/50000**.
#   - Probabilidade a priori de qualquer paciente ter ridez de nuca: **1/20**.
# - **Se um paciente tem rigidez de nuca(evidência), qual aé a probabilidade a posteriori de ele ter meningite?**

# %% [markdown]
# - Dado
#  - M: meningite
#  - R: rigidez no pescoço

# %% [markdown]
# ![bayes2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # GaussianNB, MultinomialNB, BernoulliNB (o que os algoritmos Naive Bayes fazem debaixo dos panos)

# %% [markdown]
# # Suavização de Laplace

# %% [markdown]
# # Naive Bayes (aplicação prática em Python: resolvendo um problema)

# %% [markdown]
# # Naive Bayes (apresentação do exercício)

# %% [markdown]
# # Naive Bayes (solução do exercício)
